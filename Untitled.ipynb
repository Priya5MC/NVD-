# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import streamlit as st
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('NVD.csv')

# %%
data
# Out:
#              cve/id cve/sourceIdentifier            cve/published  \
# 0     CVE-1999-0095        cve@mitre.org  1988-10-01T04:00:00.000
# 1     CVE-1999-0082        cve@mitre.org  1988-11-11T05:00:00.000
# 2     CVE-1999-1471        cve@mitre.org  1989-01-01T05:00:00.000
# 3     CVE-1999-1122        cve@mitre.org  1989-07-26T04:00:00.000
# 4     CVE-1999-1467        cve@mitre.org  1989-10-26T04:00:00.000
# ...             ...                  ...                      ...
# 1995  CVE-2000-0462        cve@mitre.org  2000-05-28T04:00:00.000
# 1996  CVE-2000-0454        cve@mitre.org  2000-05-29T04:00:00.000
# 1997  CVE-2000-0455        cve@mitre.org  2000-05-29T04:00:00.000
# 1998  CVE-2000-0461        cve@mitre.org  2000-05-29T04:00:00.000
# 1999  CVE-2000-0564        cve@mitre.org  2000-05-29T04:00:00.000
#
#              cve/lastModified cve/vulnStatus cve/descriptions/0/lang  \
# 0     2019-06-11T20:29:00.263       Modified                      en
# 1     2008-09-09T12:33:40.853       Analyzed                      en
# 2     2008-09-05T20:19:36.257       Analyzed                      en
# 3     2018-05-03T01:29:04.817       Modified                      en
# 4     2017-12-19T02:29:08.393       Modified                      en
# ...                       ...            ...                     ...
# 1995  2008-09-10T19:04:43.680       Analyzed                      en
# 1996  2008-09-10T19:04:43.087       Analyzed                      en
# 1997  2008-09-10T19:04:43.147       Analyzed                      en
# 1998  2008-09-10T19:04:43.587       Analyzed                      en
# 1999  2008-09-10T19:05:03.040       Analyzed                      en
#
#                                cve/descriptions/0/value  \
# 0     The debug command in Sendmail is enabled, allo...
# 1         CWD ~root command in ftpd allows root access.
# 2     Buffer overflow in passwd in BSD based operati...
# 3     Vulnerability in restore in SunOS 4.0.3 and ea...
# 4     Vulnerability in rcp on SunOS 4.0.x allows rem...
# ...                                                 ...
# 1995  ftpd in NetBSD 1.4.2 does not properly parse e...
# 1996  Buffer overflow in Linux cdrecord allows local...
# 1997  Buffer overflow in xlockmore xlock program ver...
# 1998  The undocumented semconfig system call in BSD ...
# 1999  The guestbook CGI program in ICQ Web Front ser...
#
#      cve/descriptions/1/lang  \
# 0                         es
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1995                     NaN
# 1996                     NaN
# 1997                     NaN
# 1998                     NaN
# 1999                     NaN
#
#                                cve/descriptions/1/value  \
# 0     El comando de depuración de Sendmail está acti...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#      cve/metrics/cvssMetricV2/0/source  ...  \
# 0                         nvd@nist.gov  ...
# 1                         nvd@nist.gov  ...
# 2                         nvd@nist.gov  ...
# 3                         nvd@nist.gov  ...
# 4                         nvd@nist.gov  ...
# ...                                ...  ...
# 1995                      nvd@nist.gov  ...
# 1996                      nvd@nist.gov  ...
# 1997                      nvd@nist.gov  ...
# 1998                      nvd@nist.gov  ...
# 1999                      nvd@nist.gov  ...
#
#      cve/configurations/0/nodes/1/cpeMatch/7/vulnerable  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#       cve/configurations/0/nodes/1/cpeMatch/7/criteria  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1995                                               NaN
# 1996                                               NaN
# 1997                                               NaN
# 1998                                               NaN
# 1999                                               NaN
#
#      cve/configurations/0/nodes/1/cpeMatch/7/matchCriteriaId  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#      cve/references/0/tags/5  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1995                     NaN
# 1996                     NaN
# 1997                     NaN
# 1998                     NaN
# 1999                     NaN
#
#      cve/configurations/0/nodes/0/cpeMatch/46/vulnerable  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#      cve/configurations/0/nodes/0/cpeMatch/46/criteria  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1995                                               NaN
# 1996                                               NaN
# 1997                                               NaN
# 1998                                               NaN
# 1999                                               NaN
#
#      cve/configurations/0/nodes/0/cpeMatch/46/matchCriteriaId  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#      cve/configurations/0/nodes/0/cpeMatch/47/vulnerable  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#      cve/configurations/0/nodes/0/cpeMatch/47/criteria  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1995                                               NaN
# 1996                                               NaN
# 1997                                               NaN
# 1998                                               NaN
# 1999                                               NaN
#
#       cve/configurations/0/nodes/0/cpeMatch/47/matchCriteriaId
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
# [2000 rows x 442 columns]

# %%
new_column_names = {
    'cve/id': 'cve id',
    'cve/sourceIdentifier': 'sourceIdentifier',
    'cve/published': 'published',
    'cve/lastModified': 'lastModified',
    'cve/vulnStatus': 'Status',
    # Add more column mappings as needed
}

# %%
data.rename(columns=new_column_names, inplace=True)

# %%
def read_first_5_records(input_file):
    data = pd.read_csv(input_file)
    
    first_5_records = data.head(5)
    return first_5_records

# %%
def main():
    st.title('NVD')
    html_tmp = """
    <div style='background-color:red;'>
    <h2 style='color:white;text-align:center;'>CVE LIST</h2>
    </div>
    """
    st.markdown(html_tmp, unsafe_allow_html=True)
    st.write("First five rows")
    st.dataframe(data.head(5))

if __name__ == '__main__':
    main()
# Out:
# 2024-05-29 12:17:00.507
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\saiga\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
